# %%
import pandas as pd
import numpy as np
df=pd.read_csv("C:/Users/polla/Desktop/curso python esecencial ciencia de datos/numpy/datos1.csv",nrows=100000)

# %%
#correlacion es una relacion entre variables cuantitavias

# %%
df.head()
# Out:
#        Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  GpsLongitude  \
# 0  9500000.0          4         4             4         470.0    -89.611038
# 1   799999.0          2         2             1          71.0   -100.398136
# 2  5250000.0          3         3             2         177.0    -99.299350
# 3  8200000.0          2         3             3         156.0    -99.164989
# 4  6250000.0          3         3             3         200.0    -99.293693
#
#    GpsLatitude              Municipio            Estado
# 0    21.063482                 Merida           Yucatán
# 1    20.663553  Santiago de Querétaro         Querétaro
# 2    19.355751             Cuajimalpa  Ciudad de México
# 3    19.393514          Benito Juarez  Ciudad de México
# 4    19.356364             Cuajimalpa  Ciudad de México

# %%
np.corrcoef(df["Price"],df["SquareMeters"]) #matriz entre 2 columnas seleccionadas
#el resultado es que tanto estan tan correlacionadas
# Out:
# array([[1.        , 0.48420488],
#        [0.48420488, 1.        ]])

# %%
df.dropna(inplace= True, subset=["Price","GpsLongitude"]) #sirve para quitar los Na de datos vacios de una correlacion

# %%
np.corrcoef([df["Price"],df["SquareMeters"],df["GpsLongitude"]]) #hace un poco las correlaciones
# Out:
# array([[1.        , 0.48420488, 0.0072447 ],
#        [0.48420488, 1.        , 0.02849857],
#        [0.0072447 , 0.02849857, 1.        ]])

# %%
df.drop(inplace=True,columns= ["Municipio","Estado"])

# %%
df.corr()
# Out:
#                  Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  \
# Price         1.000000   0.419222  0.242695      0.473663      0.484205
# Bathrooms     0.419222   1.000000  0.599671      0.494557      0.385450
# Bedrooms      0.242695   0.599671  1.000000      0.412686      0.338191
# ParkingSlots  0.473663   0.494557  0.412686      1.000000      0.539152
# SquareMeters  0.484205   0.385450  0.338191      0.539152      1.000000
# GpsLongitude  0.007245   0.038880 -0.022421     -0.013443      0.028499
# GpsLatitude  -0.028550   0.037101  0.069290      0.072448      0.075074
#
#               GpsLongitude  GpsLatitude
# Price             0.007245    -0.028550
# Bathrooms         0.038880     0.037101
# Bedrooms         -0.022421     0.069290
# ParkingSlots     -0.013443     0.072448
# SquareMeters      0.028499     0.075074
# GpsLongitude      1.000000    -0.486775
# GpsLatitude      -0.486775     1.000000

# %%
corr=round(df.corr(),3)
corr.style.background_gradient () #hace un degrado de la corelacion  mas intensas
# Out:
# <style  type="text/css" >
#     #T_28170628_31d7_11eb_addd_b8763fc231c4row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_28170628_31d7_11eb_addd_b8763fc231c4row0_col1 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_28170628_31d7_11eb_addd_b8763fc231c4row0_col2 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_28170628_31d7_11eb_addd_b8763fc231c4row0_col3 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_28170628_31d7_11eb_addd_b8763fc231c4row0_col4 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_28170628_31d7_11eb_addd_b8763fc231c4row0_col5 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_28170628_31d7_11eb_addd_b8763fc231c4row0_col6 {
#             background-color:  #bdc8e1;
#             color:  #000000;
# ...
