# %%
import pandas as pd
df= pd.read_csv("C:/Users/polla/Desktop/curso python esecencial ciencia de datos/evaluar eficeincia del codigo/datos1.csv")

# %%
df.head()
# Out:
#        Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  GpsLongitude  \
# 0  9500000.0          4         4             4         470.0    -89.611038
# 1   799999.0          2         2             1          71.0   -100.398136
# 2  5250000.0          3         3             2         177.0    -99.299350
# 3  8200000.0          2         3             3         156.0    -99.164989
# 4  6250000.0          3         3             3         200.0    -99.293693
#
#    GpsLatitude              Municipio            Estado
# 0    21.063482                 Merida           Yucatán
# 1    20.663553  Santiago de Querétaro         Querétaro
# 2    19.355751             Cuajimalpa  Ciudad de México
# 3    19.393514          Benito Juarez  Ciudad de México
# 4    19.356364             Cuajimalpa  Ciudad de México

# %%
df["Price"].head()# muestra la fila  seleccionada
# Out:
# 0    9500000.0
# 1     799999.0
# 2    5250000.0
# 3    8200000.0
# 4    6250000.0
# Name: Price, dtype: float64

# %%
df[100:103] # hace muestreo de intervalos
# Out:
#           Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  \
# 100  12000000.0          2         3             2         400.0
# 101  15990000.0          3         3             4         417.0
# 102  11950000.0          3         3             3         400.0
#
#      GpsLongitude  GpsLatitude     Municipio            Estado
# 100    -99.256369    19.425055  Huixquilucan  Estado de México
# 101    -99.288625    19.424274  Huixquilucan  Estado de México
# 102    -99.262716    19.403509  Huixquilucan  Estado de México

# %%
df[df["Price"]!=9500000].head() #muestra precios menores que lo establecido dentro de un array   <   ==  > "!" de abajo y arriba"
# Out:
#         Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  GpsLongitude  \
# 1    799999.0          2         2             1          71.0   -100.398136
# 2   5250000.0          3         3             2         177.0    -99.299350
# 3   8200000.0          2         3             3         156.0    -99.164989
# 4   6250000.0          3         3             3         200.0    -99.293693
# 5  19750000.0          3         3             4         256.0    -99.254541
#
#    GpsLatitude              Municipio            Estado
# 1    20.663553  Santiago de Querétaro         Querétaro
# 2    19.355751             Cuajimalpa  Ciudad de México
# 3    19.393514          Benito Juarez  Ciudad de México
# 4    19.356364             Cuajimalpa  Ciudad de México
# 5    19.385992             Cuajimalpa  Ciudad de México

# %%
df[df["Estado"]=="Ciudad de México"].head() # muestra todo los estados de ciudad de mexico
# Out:
#         Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  GpsLongitude  \
# 2   5250000.0          3         3             2         177.0    -99.299350
# 3   8200000.0          2         3             3         156.0    -99.164989
# 4   6250000.0          3         3             3         200.0    -99.293693
# 5  19750000.0          3         3             4         256.0    -99.254541
# 7   6300000.0          2         2             2         140.0    -99.173591
#
#    GpsLatitude      Municipio            Estado
# 2    19.355751     Cuajimalpa  Ciudad de México
# 3    19.393514  Benito Juarez  Ciudad de México
# 4    19.356364     Cuajimalpa  Ciudad de México
# 5    19.385992     Cuajimalpa  Ciudad de México
# 7    19.396537  Benito Juarez  Ciudad de México

# %% [markdown]
# **El amperson muestra que cumpla las condiciones  (&) y   muestra que cumpla solo una codicion una o la otra(|)

# %%
df[(df["Estado"]=="Ciudad de México") & (df["Municipio"]=="Cuajimalpa")].head()#& (df["SquareMeters"]==359)] # anadir mas filtros para la busqueda de
# Out:
#          Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  GpsLongitude  \
# 2    5250000.0          3         3             2         177.0    -99.299350
# 4    6250000.0          3         3             3         200.0    -99.293693
# 5   19750000.0          3         3             4         256.0    -99.254541
# 11  22950000.0          2         2             4         359.0    -99.265160
# 14   5500000.0          2         3             2         195.0    -99.293300
#
#     GpsLatitude   Municipio            Estado
# 2     19.355751  Cuajimalpa  Ciudad de México
# 4     19.356364  Cuajimalpa  Ciudad de México
# 5     19.385992  Cuajimalpa  Ciudad de México
# 11    19.389347  Cuajimalpa  Ciudad de México
# 14    19.362600  Cuajimalpa  Ciudad de México

# %%
df[df.Municipio.isin(["Huixquilucan","Cuajimalpa"])].head() #filtro de nombres
# Out:
#          Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  GpsLongitude  \
# 2    5250000.0          3         3             2         177.0    -99.299350
# 4    6250000.0          3         3             3         200.0    -99.293693
# 5   19750000.0          3         3             4         256.0    -99.254541
# 8    9900000.0          3         3             2         199.0    -99.286972
# 11  22950000.0          2         2             4         359.0    -99.265160
#
#     GpsLatitude     Municipio            Estado
# 2     19.355751    Cuajimalpa  Ciudad de México
# 4     19.356364    Cuajimalpa  Ciudad de México
# 5     19.385992    Cuajimalpa  Ciudad de México
# 8     19.388187  Huixquilucan  Estado de México
# 11    19.389347    Cuajimalpa  Ciudad de México

# %%
df[pd.isna(df["Estado"])].head() # Muestra  datos perdidos  o los NA VACIOS
# Out:
#           Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  \
# 1687  4148225.0          2         3             2         113.0
# 1688  3500000.0          2         3             2         180.0
# 1689  2500000.0          2         3             1         113.0
# 1690  9705000.0          2         2             2         153.0
# 1691  9200000.0          3         3             3         243.0
#
#       GpsLongitude  GpsLatitude Municipio Estado
# 1687           NaN          NaN       NaN    NaN
# 1688           NaN          NaN       NaN    NaN
# 1689           NaN          NaN       NaN    NaN
# 1690           NaN          NaN       NaN    NaN
# 1691           NaN          NaN       NaN    NaN

# %%
len(df[pd.isna(df["Estado"])].head())#valores en concreto  del filtro en este caso son 5 NA
# Out:
# 5
