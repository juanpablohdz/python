# %%
import pandas as pd

df=pd.read_csv("C:/Users/polla/Desktop/curso python esecencial ciencia de datos/evaluar eficeincia del codigo/datos1.csv",nrows=1e6)
#nrows=1e6 10 elevado ala 6  hace 1 millon de datos

# %%
dfduplicate=df.append(df) # mismo df por duplicadado

# %%
dfduplicate=dfduplicate.sample(frac=1) #reordenamiento

# %%
dfduplicate.head(10)
# Out:
#            Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  \
# 6532    730000.0          2         3             2          86.0
# 10437  2450000.0          3         3             2         480.0
# 8842   1795000.0          2         2             2          82.0
# 7146    990000.0          3         3             1          85.0
# 5033   3141600.0          2         2             1          64.0
# 785    2300000.0          3         3             2         130.0
# 8118   3250000.0          2         4             4         625.0
# 2447   3350000.0          4         3             3         513.0
# 11724  1450000.0          2         3             2         160.0
# 12499  1479602.0          3         3             2         214.0
#
#        GpsLongitude  GpsLatitude              Municipio               Estado
# 6532    -100.395297    20.982897      San José Iturbide           Guanajuato
# 10437    -89.521437    21.072211    Conkal Municipality              Yucatán
# ...

# %%
dfclean=dfduplicate.drop_duplicates () # ya eliminamos los datos duplicados

# %%
len(dfclean)==len(df) #quiere decir que no es lo mismo la df   de los mismos datos   si no se han quitado datos duplicados
# Out:
# False

# %%
len(df)#dataframe inicial filas
# Out:
# 16459

# %%
len(dfduplicate)#base de datos artificial creada para limpiar datos
# Out:
# 32918

# %%
len(dfclean)#df limpia sin datos  repetidos
# Out:
# 15517

# %%
dfclean.drop_duplicates(subset= "Municipio")#se puede ver las columnas repetidas
# Out:
#            Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  \
# 6532    730000.0          2         3             2          86.0
# 10437  2450000.0          3         3             2         480.0
# 8842   1795000.0          2         2             2          82.0
# 7146    990000.0          3         3             1          85.0
# 5033   3141600.0          2         2             1          64.0
# ...          ...        ...       ...           ...           ...
# 11884   550000.0          1         1             1          90.0
# 14359  1325000.0          3         3             1          89.0
# 1537   2900000.0          4         4             4         397.0
# 9817   1100000.0          1         3             1         400.0
# 14886   490000.0          1         2             2          97.0
#
#        GpsLongitude  GpsLatitude             Municipio            Estado
# 6532    -100.395297    20.982897     San José Iturbide        Guanajuato
# ...

# %%
df.dropna()
#si no muestra nada entonces nuestra base de datos no tienen Nan y si aparece es por que tenemos datos faltantes
# Out:
#            Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  \
# 0      9500000.0          4         4             4         470.0
# 1       799999.0          2         2             1          71.0
# 2      5250000.0          3         3             2         177.0
# 3      8200000.0          2         3             3         156.0
# 4      6250000.0          3         3             3         200.0
# ...          ...        ...       ...           ...           ...
# 16099  4240000.0          4         4             3         379.0
# 16100  4000000.0          3         3             3         312.0
# 16101  1250000.0          2         2             2         140.0
# 16102  2950000.0          4         3             2         230.0
# 16103   830000.0          2         3             1         171.0
#
#        GpsLongitude  GpsLatitude              Municipio               Estado
# 0        -89.611038    21.063482                 Merida              Yucatán
# ...

# %%
df.dropna(thresh=1 )#llena de informacion de datos relevantes relevante columna
# Out:
#            Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  \
# 0      9500000.0          4         4             4         470.0
# 1       799999.0          2         2             1          71.0
# 2      5250000.0          3         3             2         177.0
# 3      8200000.0          2         3             3         156.0
# 4      6250000.0          3         3             3         200.0
# ...          ...        ...       ...           ...           ...
# 16454  5300000.0          3         3             2         428.0
# 16455  3400000.0          4         4             2        2000.0
# 16456  1848000.0          3         3             2         128.0
# 16457  1900000.0          3         3             2         125.0
# 16458  3200000.0          4         4             3         360.0
#
#        GpsLongitude  GpsLatitude              Municipio            Estado
# 0        -89.611038    21.063482                 Merida           Yucatán
# ...

# %%
df.dropna(thresh=9 ) #en este caso son las 9 columnas
# Out:
#            Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  \
# 0      9500000.0          4         4             4         470.0
# 1       799999.0          2         2             1          71.0
# 2      5250000.0          3         3             2         177.0
# 3      8200000.0          2         3             3         156.0
# 4      6250000.0          3         3             3         200.0
# ...          ...        ...       ...           ...           ...
# 16099  4240000.0          4         4             3         379.0
# 16100  4000000.0          3         3             3         312.0
# 16101  1250000.0          2         2             2         140.0
# 16102  2950000.0          4         3             2         230.0
# 16103   830000.0          2         3             1         171.0
#
#        GpsLongitude  GpsLatitude              Municipio               Estado
# 0        -89.611038    21.063482                 Merida              Yucatán
# ...

# %%
df.dropna(thresh=len(df.columns)-2 )#una manera de usar bien el codigo
#el codigo dice que como maximo tengamos  -1  dato dfaltante
# Out:
#            Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  \
# 0      9500000.0          4         4             4         470.0
# 1       799999.0          2         2             1          71.0
# 2      5250000.0          3         3             2         177.0
# 3      8200000.0          2         3             3         156.0
# 4      6250000.0          3         3             3         200.0
# ...          ...        ...       ...           ...           ...
# 16454  5300000.0          3         3             2         428.0
# 16455  3400000.0          4         4             2        2000.0
# 16456  1848000.0          3         3             2         128.0
# 16457  1900000.0          3         3             2         125.0
# 16458  3200000.0          4         4             3         360.0
#
#        GpsLongitude  GpsLatitude              Municipio            Estado
# 0        -89.611038    21.063482                 Merida           Yucatán
# ...

# %%
df.dropna (subset=["Municipio"]) # nos duevuelve un data frame sin Nan en esa columna
# Out:
#            Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  \
# 0      9500000.0          4         4             4         470.0
# 1       799999.0          2         2             1          71.0
# 2      5250000.0          3         3             2         177.0
# 3      8200000.0          2         3             3         156.0
# 4      6250000.0          3         3             3         200.0
# ...          ...        ...       ...           ...           ...
# 16099  4240000.0          4         4             3         379.0
# 16100  4000000.0          3         3             3         312.0
# 16101  1250000.0          2         2             2         140.0
# 16102  2950000.0          4         3             2         230.0
# 16103   830000.0          2         3             1         171.0
#
#        GpsLongitude  GpsLatitude              Municipio               Estado
# 0        -89.611038    21.063482                 Merida              Yucatán
# ...
