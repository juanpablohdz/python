# %%
import pandas as pd
df=pd.read_csv("C:/Users/polla/Desktop/curso python esecencial ciencia de datos/evaluar eficeincia del codigo/datos1.csv")

# %%
df.head(24)
# Out:
#          Price  Bathrooms  Bedrooms  ParkingSlots  SquareMeters  GpsLongitude  \
# 0    9500000.0          4         4             4         470.0    -89.611038
# 1     799999.0          2         2             1          71.0   -100.398136
# 2    5250000.0          3         3             2         177.0    -99.299350
# 3    8200000.0          2         3             3         156.0    -99.164989
# 4    6250000.0          3         3             3         200.0    -99.293693
# 5   19750000.0          3         3             4         256.0    -99.254541
# 6    7200000.0          3         3             4         599.0    -89.614570
# 7    6300000.0          2         2             2         140.0    -99.173591
# 8    9900000.0          3         3             2         199.0    -99.286972
# 9    6500000.0          2         3             2         178.0    -99.204056
# 10   4990000.0          2         2             2          90.0    -99.164989
# ...

# %%
df.groupby(by="SquareMeters")["Price"].max() #muestra la cantidad de maximos de ambas tablas solo en debe adminitir  int, float
# Out:
# SquareMeters
# 40.0       2868695.0
# 41.0       2840000.0
# 42.0       2679720.0
# 43.0       2367630.0
# 44.0       2700000.0
#              ...
# 1940.0    20500000.0
# 1951.0     5500000.0
# 1956.0     9800000.0
# 1987.0     1600000.0
# 2000.0    19300000.0
# Name: Price, Length: 897, dtype: float64

# %%
df.groupby(by="SquareMeters")["Price"].mean()#media de los datos  seria la media del precio para los metros cuadrados
# Out:
# SquareMeters
# 40.0      1.258595e+06
# 41.0      1.610000e+06
# 42.0      1.205122e+06
# 43.0      1.011037e+06
# 44.0      1.130379e+06
#               ...
# 1940.0    2.050000e+07
# 1951.0    5.500000e+06
# 1956.0    9.800000e+06
# 1987.0    1.600000e+06
# 2000.0    8.031765e+06
# Name: Price, Length: 897, dtype: float64

# %%
df.groupby(by="SquareMeters")["Price"].min() #minimo de los datos
# Out:
# SquareMeters
# 40.0        250000.0
# 41.0        380000.0
# 42.0        290000.0
# 43.0        326000.0
# 44.0        290000.0
#              ...
# 1940.0    20500000.0
# 1951.0     5500000.0
# 1956.0     9800000.0
# 1987.0     1600000.0
# 2000.0     1190000.0
# Name: Price, Length: 897, dtype: float64

# %%
df.groupby(by="SquareMeters")["Price"].count()#numero de casos
# Out:
# SquareMeters
# 40.0      18
# 41.0       2
# 42.0      11
# 43.0       9
# 44.0      14
#           ..
# 1940.0     1
# 1951.0     1
# 1956.0     1
# 1987.0     1
# 2000.0    17
# Name: Price, Length: 897, dtype: int64

# %%
df.groupby(by="SquareMeters")["Price"].describe() #muestra resumen estadistico para cada metro cuadrado del precio
# Out:
#               count          mean           std         min         25%  \
# SquareMeters
# 40.0           18.0  1.258595e+06  1.003817e+06    250000.0    365000.0
# 41.0            2.0  1.610000e+06  1.739483e+06    380000.0    995000.0
# 42.0           11.0  1.205122e+06  9.513452e+05    290000.0    433750.0
# 43.0            9.0  1.011037e+06  7.634704e+05    326000.0    399600.0
# 44.0           14.0  1.130379e+06  6.774624e+05    290000.0    696250.0
# ...             ...           ...           ...         ...         ...
# 1940.0          1.0  2.050000e+07           NaN  20500000.0  20500000.0
# 1951.0          1.0  5.500000e+06           NaN   5500000.0   5500000.0
# 1956.0          1.0  9.800000e+06           NaN   9800000.0   9800000.0
# 1987.0          1.0  1.600000e+06           NaN   1600000.0   1600000.0
# 2000.0         17.0  8.031765e+06  6.040030e+06   1190000.0   3400000.0
#
#                      50%         75%         max
# SquareMeters
# ...

# %%
df.groupby(by="SquareMeters")["Price","Bathrooms"].mean() #muestra media y se  puede hacer con cualquier  columna  
#deben ser del mismo caracter  float , int , texto etc...
# Out:
# C:\Users\polla\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                      Price  Bathrooms
# SquareMeters
# 40.0          1.258595e+06   1.111111
# 41.0          1.610000e+06   1.000000
# 42.0          1.205122e+06   1.090909
# 43.0          1.011037e+06   1.000000
# 44.0          1.130379e+06   1.214286
# ...                    ...        ...
# 1940.0        2.050000e+07   4.000000
# 1951.0        5.500000e+06   1.000000
# 1956.0        9.800000e+06   4.000000
# 1987.0        1.600000e+06   1.000000
# 2000.0        8.031765e+06   3.294118
#
# [897 rows x 2 columns]

# %%
df.groupby(by="SquareMeters")["Price"].max() - df.groupby(by="SquareMeters")["Price"].min() #restar el maximo y el minimo 
#ver rango de valores para cada metro cuadrado
# Out:
# SquareMeters
# 40.0       2618695.0
# 41.0       2460000.0
# 42.0       2389720.0
# 43.0       2041630.0
# 44.0       2410000.0
#              ...
# 1940.0           0.0
# 1951.0           0.0
# 1956.0           0.0
# 1987.0           0.0
# 2000.0    18110000.0
# Name: Price, Length: 897, dtype: float64

# %%
dfCDMX=df[df.Estado.isin(["Benito Juarez","Álvaro Obregón"])]#seleccionar ciudades que salgan de ese estado  EJEMPLO CDMX  a Benito Juarez

# %%
dfCDMX.groupby(by= ["Bathrooms","Bedrooms"])["Price"].mean()
# Out:
# Series([], Name: Price, dtype: float64)

# %%
mygroupby=dfCDMX.groupby(by= ["Bathrooms","Bedrooms"])["Price"]

# %%
mygroupby.head()
# Out:
# Series([], Name: Price, dtype: float64)
